# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import SGDClassifier, RidgeClassifier, LogisticRegression
from sklearn.model_selection import ShuffleSplit, cross_val_score, KFold
from scipy import sparse
# %matplotlib inline

# %%
train = pd.read_csv('linear_train.txt', sep=',', header=None)
train.columns = ['word', 'y']
test = pd.read_csv('linear_test.txt', sep=',', header=None)
test.columns = ['word']
print(train.head())
print(test.head())
test.shape
# Out:
#         word  y
# 0  ﻿Аалтонен  1
# 1        Аар  0
# 2      Аарон  0
# 3      ААРОН  0
# 4     Аарона  0
#      word
# 0  ﻿Аалто
# 1     ААР
# 2    Аара
# 3    Ааре
# 4   Аарон
# (188920, 1)

# %%
train['word'] = train['word'].apply(lambda x: '*' + x + '#')
test['word'] = test['word'].apply(lambda x: '*' + x + '#')

# %%
train.head()
# Out:
#           word  y
# 0  *﻿Аалтонен#  1
# 1        *Аар#  0
# 2      *Аарон#  0
# 3      *ААРОН#  0
# 4     *Аарона#  0

# %%
def get_lens_features(df):
    lens = pd.DataFrame()
    for i in range(5, 20):
        lens[str(i)] = df['word'].apply(lambda x: 1 if (len(x) == i) else 0)
    return lens
get_lens_features(train).as_matrix().shape
# Out:
# (101408, 15)

# %%
not_surnames_set = set(train[train['y'] == 0]['word'])
surnames_set = set(train[train['y'] == 1]['word'])
print(len(not_surnames_set))
len(surnames_set)
# Out:
# 90770
# 10638

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(min_df=5, max_df=.7,
                             max_features=None,
                             ngram_range=(2, 5),
                             lowercase=False,
                             analyzer='char_wb', 
                             binary=True)
vectorizer.fit(train['word'])
#vectorizer.fit(pd.concat([train['word'], test['word']], axis=0))
X = vectorizer.transform(train['word'])
print(X.shape)
X = sparse.hstack([X, get_lens_features(train).as_matrix()])
X_test = vectorizer.transform(test['word'])
print(X_test.shape)
X_test = sparse.hstack([X_test, get_lens_features(test).as_matrix()])
print(X_test.shape)
X.shape
# Out:
# (101408, 82979)
# (188920, 82979)
# (188920, 82994)
# (101408, 82994)

# %%
for C in [.2, .15, .1, .05]:
    print(cross_val_score(LogisticRegression(penalty='l2',class_weight='balanced',max_iter=300,C=C), X, train['y'], 
                cv=ShuffleSplit(n_splits=5, test_size=0.6, random_state=0), 
                scoring='roc_auc').mean())
# Out:
# 0.904442748052
# 0.904831956423
# 0.905006757268
# 0.904107448837

# %%
from collections import Counter
def generate_features(W_train, n_features=4, n_top=1000):
    cntr = Counter(W_train.apply(lambda x: x[-4:]))
    print(cntr.most_common(10))
    for i in range(n_top):
        X_i = W_train.apply(lambda w: 1 if w.endswith(cntr.most_common(n_top)[i][0]) else 0)
        print(X_i)
    #X = W_train.apply()

generate_features(train['word'], n_top=1)
# Out:
# [('ость', 1357), ('ками', 1132), ('ание', 1072), ('нием', 959), ('ости', 934), ('ение', 855), ('ания', 768), ('стью', 710), ('ения', 617), ('иями', 561)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-f7ef4204830f> in <module>()
#       8     #X = W_train.apply()
#       9
# ---> 10 generate_features(train['word'], n_top=1)
#
# <ipython-input-73-f7ef4204830f> in generate_features(W_train, n_features, n_top)
#       4     print(cntr.most_common(10))
#       5     for i in range(n_top):
# ----> 6         X_i = W_train.apply(lambda w: 1 if w.endswith(cntr.most_common(n_top)[i][0]) else 0)
#       7         print(X_i)
#       8     #X = W_train.apply()
#
# C:\Users\Andrey\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\src\inference.pyx in pandas.lib.map_infer (pandas\lib.c:62658)()
#
# <ipython-input-73-f7ef4204830f> in <lambda>(w)
#       4     print(cntr.most_common(10))
#       5     for i in range(n_top):
# ----> 6         X_i = W_train.apply(lambda w: 1 if w.endswith(cntr.most_common(n_top)[i][0]) else 0)
#       7         print(X_i)
#       8     #X = W_train.apply()
#
# C:\Users\Andrey\Anaconda3\lib\collections\__init__.py in most_common(self, n)
#     546         if n is None:
#     547             return sorted(self.items(), key=_itemgetter(1), reverse=True)
# --> 548         return _heapq.nlargest(n, self.items(), key=_itemgetter(1))
#     549
#     550     def elements(self):
#
# C:\Users\Andrey\Anaconda3\lib\heapq.py in nlargest(n, iterable, key)
#     536         else:
#     537             result = max(it, default=sentinel, key=key)
# --> 538         return [] if result is sentinel else [result]
#     539
#     540     # When n>=size, it's faster to use sorted()
#
# KeyboardInterrupt:

# %%
clf = LogisticRegression(penalty='l2', class_weight='balanced', max_iter=300, C=.1)
clf.fit(X, train['y'])
#roc_auc_score(test['y'], clf.predict(X_test))
roc_auc_score(train['y'], clf.predict(X))
# Out:
# 0.92274761998943544

# %%
res = clf.predict_proba(X_test)
#res = np.array(res).max(axis=1)
res[:10]
# Out:
# array([[ 0.34198266,  0.65801734],
#        [ 0.23194685,  0.76805315],
#        [ 0.33672616,  0.66327384],
#        [ 0.61904632,  0.38095368],
#        [ 0.33843261,  0.66156739],
#        [ 0.45350457,  0.54649543],
#        [ 0.25894732,  0.74105268],
#        [ 0.40797426,  0.59202574],
#        [ 0.40797426,  0.59202574],
#        [ 0.40461412,  0.59538588]])

# %%
submission = pd.read_csv("linear_ans_example.txt")
submission['Id'] = [i for i in range(len(res))]
submission['Answer'] = 1 - res
#submission.head(50)
submission.to_csv('logregr_ngram_2_5_suf_pref_len_c01_balanced.txt', index=False)
submission.head()
# Out:
#    Id    Answer
# 0   0  0.658017
# 1   1  0.768053
# 2   2  0.663274
# 3   3  0.380954
# 4   4  0.661567

# %%
# SGDClassifier
clf = SGDClassifier(penalty='l2', loss='log')
clf.fit(X, train['y'])
X_test = vectorizer.transform(test['word'])
test['y'] = clf.predict(X_test)

# %%
test2 = test.copy()
def check_in_train(df):
    if (df[0] in not_surnames_set):
        df[1] = 0
    else:
        if (df[0] in surnames_set):
            df[1] = 1
    return df

test2[['word', 'y']] = test2[['word', 'y']].apply(lambda row: check_in_train(row), axis=1)
test2
# Out:
#              word  y
# 0          ﻿Аалто  0
# 1             ААР  0
# 2            Аара  0
# 3            Ааре  0
# 4           Аарон  0
# 5          Аароне  0
# 6         Ааронов  0
# 7         Аароном  0
# 8         Аароном  0
# 9          Аарону  0
# 10         Аарону  0
# 11          Аахен  0
# 12         Аахене  0
# 13        Аахеном  0
# 14             АБ  0
# 15         Абадан  0
# 16        Абадане  0
# 17       Абаданом  0
# 18          Абаев  1
# 19         Абаева  1
# 20        Абаевым  1
# 21         Абажур  0
# 22        абажура  0
# 23      абажурами  0
# 24       абажурах  0
# 25        абажуре  0
# 26       абажуров  0
# 27        абажуру  0
# 28           Абак  0
# 29           АБАК  0
# ...           ... ..
# 188890     ящичка  0
# 188891    ящичкам  0
# 188892   ящичками  0
# 188893     ящичке  0
# 188894     ящички  0
# 188895     Ящички  0
# 188896    ящичком  0
# 188897      ящуре  0
# 188898     ящуром  0
# 188899         ёж  0
# 188900         Ёж  0
# 188901       ёжик  0
# 188902      ёжика  0
# 188903      ёжике  0
# 188904     ёжиком  0
# 188905       ёлка  0
# 188906     ёлками  0
# 188907       ёлке  0
# 188908       ёлки  0
# 188909       Ёлки  0
# 188910       ёлку  0
# 188911     ёлочек  0
# 188912     ёлочка  0
# 188913     ёлочки  0
# 188914   ёмкостей  0
# 188915    ёмкости  0
# 188916    Ёмкости  0
# 188917    Ёмкость  0
# 188918   ёмкостью  0
# 188919   ёмкостях  0
#
# [188920 rows x 2 columns]

# %%
test[test2['y'] != test['y']]
# Out:
#                  word  y
# 545            АВГУСТ  0
# 891         автокаско  0
# 948         автоматов  0
# 1265            агент  0
# 1290        агентство  0
# 1433    агрегирования  0
# 1928             Азов  0
# 2474              акт  0
# 2608             акты  0
# 2838        алгоритмы  0
# 2983              Али  0
# 3093        алкоголик  0
# 3213          Аллисон  1
# 3589            альфа  0
# 3841            Амине  0
# 3843           аминов  0
# 3950      амортизация  0
# 4496            Андре  0
# 5148       Антоновича  0
# 5885            Арене  0
# 6214        Арнольдом  0
# 6257          арсенал  0
# 6347      артиллерист  0
# 6769          аспекты  0
# 7661       африканцев  0
# 7664        Африканцы  0
# 7743           Ахмада  0
# 7822              Аша  0
# 8054           бабник  0
# 8431              Бак  0
# ...               ... ..
# 183686         штучка  0
# 183690         штучки  0
# 183873          шутка  0
# 184230          щитки  0
# 184302          Эббот  0
# 184519           Эдди  0
# 184574        Эдисона  0
# 184688          Эймса  0
# 184811       экзамены  0
# 184867       экзотика  0
# 185001    экономистом  0
# 185017       экономка  0
# 185305   эксплуатация  0
# 185602           Элам  0
# 185889        элемент  0
# 185931            Эли  0
# 186037      эллипсоид  0
# 186046          Эллис  0
# 186430         Энджел  0
# 186681       эпидемия  0
# 186810           Эппл  0
# 186973        Эрнесту  0
# 187464            это  0
# 187581            эхо  0
# 187617          Эшере  0
# 187621           Эшли  0
# 187866            Юму  0
# 187873           Юнга  0
# 187882           Юнги  0
# 188580         японец  0
#
# [1200 rows x 2 columns]

# %%
test2[test2['y'] != test['y']]
# Out:
#                  word  y
# 545            АВГУСТ  1
# 891         автокаско  1
# 948         автоматов  1
# 1265            агент  1
# 1290        агентство  1
# 1433    агрегирования  1
# 1928             Азов  1
# 2474              акт  1
# 2608             акты  1
# 2838        алгоритмы  1
# 2983              Али  1
# 3093        алкоголик  1
# 3213          Аллисон  0
# 3589            альфа  1
# 3841            Амине  1
# 3843           аминов  1
# 3950      амортизация  1
# 4496            Андре  1
# 5148       Антоновича  1
# 5885            Арене  1
# 6214        Арнольдом  1
# 6257          арсенал  1
# 6347      артиллерист  1
# 6769          аспекты  1
# 7661       африканцев  1
# 7664        Африканцы  1
# 7743           Ахмада  1
# 7822              Аша  1
# 8054           бабник  1
# 8431              Бак  1
# ...               ... ..
# 183686         штучка  1
# 183690         штучки  1
# 183873          шутка  1
# 184230          щитки  1
# 184302          Эббот  1
# 184519           Эдди  1
# 184574        Эдисона  1
# 184688          Эймса  1
# 184811       экзамены  1
# 184867       экзотика  1
# 185001    экономистом  1
# 185017       экономка  1
# 185305   эксплуатация  1
# 185602           Элам  1
# 185889        элемент  1
# 185931            Эли  1
# 186037      эллипсоид  1
# 186046          Эллис  1
# 186430         Энджел  1
# 186681       эпидемия  1
# 186810           Эппл  1
# 186973        Эрнесту  1
# 187464            это  1
# 187581            эхо  1
# 187617          Эшере  1
# 187621           Эшли  1
# 187866            Юму  1
# 187873           Юнга  1
# 187882           Юнги  1
# 188580         японец  1
#
# [1200 rows x 2 columns]

# %%
ans = test2.copy()
ans.drop('word', inplace=True, axis=1)
ans.columns = ['Answer']
ans.to_csv('SGD_3_8_l2_log_useknown.txt')

# %%
cross_val_score(RidgeClassifier(normalize=True), X, train['y'], 
                cv=ShuffleSplit(n_splits=3, test_size=0.6, random_state=0), 
                scoring='roc_auc').mean()
# Out:
# 0.89222263755976072

# %%
cross_val_score(svm.SVC(), X, train['y'], 
                cv=ShuffleSplit(n_splits=3, test_size=0.6, random_state=0), 
                scoring='roc_auc').mean()
# Out:
# 0.87390083894683634

# %%
from sklearn import svm

# %%
svm.SVC()
