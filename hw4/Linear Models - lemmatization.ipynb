# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.linear_model import SGDClassifier, RidgeClassifier, LogisticRegression
from sklearn.model_selection import ShuffleSplit, cross_val_score, KFold, train_test_split
from scipy import sparse
import re
import time
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %%time
row = 0
first = True
Id = []
X = []
lemmas = []
y = []
train = pd.DataFrame(columns=['Id', 'X', 'y'])
with open('task2_lemmas_train', encoding='utf-8') as f:
    for line in f:
        if (row > 0):
            ws = line.split(',')
            Id.append(ws[0])
            X.append(ws[1])
            lemmas.append(ws[2].split('+')[0])
            y.append(ws[2].split('+')[1][0])
            if (len(ws) > 3):
                Id.append(ws[0])
                X.append(ws[1])
                lemmas.append(ws[3].split('+')[0])
                y.append(ws[3].split('+')[1][0])
        row += 1
# Out:
# Wall time: 269 ms

# %%
train = pd.DataFrame([Id, X, lemmas, y]).T
train.columns=['Id', 'X', 'lemmas', 'y']
train
# Out:
#             Id                    X          lemmas  y
# 0            1         vergognerete      vergognare  V
# 1            2         amnistiavate      amnistiare  V
# 2            3          menomazione     menomazione  N
# 3            4           sfaldavamo        sfaldare  V
# 4            5           sfodererei       sfoderare  V
# 5            6           ascondesti       ascondere  V
# 6            7        edifichereste       edificare  V
# 7            8           maschieran       maschiare  V
# 8            9        transennasser     transennare  V
# 9           10           computando       computare  V
# 10          11           accudisser        accudire  V
# 11          12         diromperanno       dirompere  V
# 12          13        intercollegai  intercollegare  V
# 13          14           integrando       integrare  V
# 14          15        sbramerebbero        sbramare  V
# 15          16    stravaccherebbero     stravaccare  V
# 16          17       oltrepassasser    oltrepassare  V
# 17          18          cauzionavan      cauzionare  V
# 18          19          scarrozzata     scarrozzare  V
# 19          20       intossicassero     intossicare  V
# 20          21             incurvan       incurvare  V
# 21          22              zufolan        zufolare  V
# 22          23          impiastrate     impiastrare  V
# 23          24      trivellerebbero      trivellare  V
# 24          25        pizzicottassi    pizzicottare  V
# 25          26      spoliticizzasti  spoliticizzare  V
# 26          27               rombar         rombare  V
# 27          28       scapricceremmo    scapricciare  V
# 28          29      intrometterebbe    intromettere  V
# 29          30       lavoricchiassi   lavoricchiare  V
# ...        ...                  ...             ... ..
# 120773  118612                colli           colle  N
# 120774  118612                colli           collo  N
# 120775  118613         inscatolerai     inscatolare  V
# 120776  118614                odori         odorare  V
# 120777  118615       cristianizzata  cristianizzare  V
# 120778  118616            sgranchii      sgranchire  V
# 120779  118617           graffiavan       graffiare  V
# 120780  118618       incardinereste     incardinare  V
# 120781  118619       vivacchieranno     vivacchiare  V
# 120782  118620           formuletta      formuletta  N
# 120783  118621          disattendon    disattendere  V
# 120784  118622            precluser      precludere  V
# 120785  118623             spalmano        spalmare  V
# 120786  118624          rinfacciavo     rinfacciare  V
# 120787  118625         ticchettammo     ticchettare  V
# 120788  118626         prevalessero       prevalere  V
# 120789  118627            inoltrate       inoltrare  V
# 120790  118628         intervenente     intervenire  A
# 120791  118629         rincasassero       rincasare  V
# 120792  118630           ospitasser        ospitare  V
# 120793  118631           disgustavo      disgustare  V
# 120794  118632            spanciate       spanciare  V
# 120795  118633                funky           funky  N
# 120796  118634            contaminò     contaminare  V
# 120797  118635             sopisser          sopire  V
# 120798  118636            posereste          posare  V
# 120799  118637           cogestiste       cogestire  V
# 120800  118638  autocorreggerebbero  autocorreggere  V
# 120801  118639       gorgogliassimo     gorgogliare  V
# 120802  118640         desecretaste     desecretare  V
#
# [120803 rows x 4 columns]

# %%
test = pd.read_csv('task2_lemmas_test')

# %% [markdown]
# ## predict class

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(min_df=5, max_df=.7,
                             max_features=None,
                             ngram_range=(3, 5),
                             lowercase=False,
                             analyzer='char_wb', 
                             binary=True)
vectorizer.fit(train['X'])
X = vectorizer.transform(train['X'])
X_test = vectorizer.transform(test['X'])
X.shape
# Out:
# (120803, 37412)

# %%
clf = LogisticRegression(multi_class='ovr', class_weight='balanced')
clf.fit(X, train['y'])
accuracy_score(train['y'], clf.predict(X))
# Out:
# 0.97552213107290386

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, train['y'], test_size=.4)

# %%
clf = LogisticRegression(multi_class='ovr')
clf.fit(X_train, y_train)
accuracy_score(y_test, clf.predict(X_test))
# Out:
# 0.94120690368776128

# %% [markdown]
# ## predict lemma

# %% [markdown]
# ### get subdatasets - train_V, train_N, train_A

# %%
def shorten_row(df, ending_len):
    i_first = max(0, len(df[0]) - ending_len)
    df[0] = df[0][i_first:].lower()
    df[1] = df[1][i_first:].lower()
    return df

# %%
# %%time
train_V = train[train['y'] == 'V']
for ending_len in range(3, 10):
    train_V[['X_suf_' + str(ending_len), 'lemma_suf_' + str(ending_len)]] \
        = train_V[['X', 'lemmas']].apply(lambda row: shorten_row(row, ending_len), axis=1)
# Out:
# C:\Users\Andrey\Anaconda3\lib\site-packages\pandas\core\frame.py:2378: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# Wall time: 1min 45s

# %%
# %%time
train_N = train[train['y'] == 'N']
for ending_len in range(3, 10):
    train_N[['X_suf_' + str(ending_len), 'lemma_suf_' + str(ending_len)]] \
        = train_N[['X', 'lemmas']].apply(lambda row: shorten_row(row, ending_len), axis=1)
print(train_N.shape)
# Out:
# C:\Users\Andrey\Anaconda3\lib\site-packages\pandas\core\frame.py:2378: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# (10240, 18)
# Wall time: 11.3 s

# %%
# %%time
train_A = train[train['y'] == 'A']
for ending_len in range(3, 10):
    train_A[['X_suf_' + str(ending_len), 'lemma_suf_' + str(ending_len)]] \
        = train_A[['X', 'lemmas']].apply(lambda row: shorten_row(row, ending_len), axis=1)
print(train_A.shape)
# Out:
# C:\Users\Andrey\Anaconda3\lib\site-packages\pandas\core\frame.py:2378: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# (13942, 18)
# Wall time: 14.9 s

# %%
train_A.head()
# Out:
#     Id              X        lemmas  y X_suf_3 lemma_suf_3 X_suf_4  \
# 37  38      balenieri     baleniero  A     eri         ero    ieri
# 48  49         osanti         osare  A     nti          re    anti
# 49  50       rialzata      rialzato  A     ata         ato    zata
# 55  56  rivaleggiante  rivaleggiare  A     nte          re    ante
# 61  62     cospiranti     cospirare  A     nti          re    anti
#
#    lemma_suf_4 X_suf_5 lemma_suf_5 X_suf_6 lemma_suf_6  X_suf_7 lemma_suf_7  \
# 37        iero   nieri       niero  enieri      eniero  lenieri     leniero
# 48         are   santi        sare  osanti       osare   osanti       osare
# 49        zato   lzata       lzato  alzata      alzato  ialzata     ialzato
# 55         are   iante        iare  giante       giare  ggiante      ggiare
# 61         are   ranti        rare  iranti       irare  piranti      pirare
#
#      X_suf_8 lemma_suf_8    X_suf_9 lemma_suf_9
# 37  alenieri    aleniero  balenieri   baleniero
# 48    osanti       osare     osanti       osare
# 49  rialzata    rialzato   rialzata    rialzato
# 55  eggiante     eggiare  leggiante    leggiare
# 61  spiranti     spirare  ospiranti    ospirare

# %% [markdown]
# # predict lemmas separately for each class

# %%
from collections import Counter

def get_most_frequent_lemma(series):
    cntr = Counter(series)
    return cntr.most_common(1)[0][0]

# returns dict: str(word_ending) -> str(lemma_ending)
# df contains columns: X_suf_{i}, lemma_suf_{i}
def get_lemmarization_dict(df):
    x_to_lemms_suffs = dict()
    bad_x_suf_set = set()
    # suf with length 3
    for x_suf in df['X_suf_3'].unique():
        if (df[df['X_suf_3'] == x_suf]['lemma_suf_3'].unique().shape[0] == 1):
            #print(x_suf, ' - very good suf')
            x_to_lemms_suffs[x_suf] = list(df[df['X_suf_3'] == x_suf]['lemma_suf_3'])[0]
        else:
            bad_x_suf_set.add(x_suf)
            x_to_lemms_suffs[x_suf] = get_most_frequent_lemma(df[df['X_suf_3'] == x_suf]['lemma_suf_3'])
    
    start = 4
    end = 10
    # suf with lengths 4..9
    for i in range(start, end):
        x_suf_i = 'X_suf_' + str(i)
        lemma_suf_i = 'lemma_suf_' + str(i)
        for x_suf in df[x_suf_i].unique():
            #if word length < curr suffix length add to dict as an exception
            if (len(x_suf) < i):
                x_to_lemms_suffs[x_suf] = list(df[df[x_suf_i] == x_suf][lemma_suf_i])[0]
                continue

            if (x_suf[1:] in bad_x_suf_set):
                if (df[df[x_suf_i] == x_suf][lemma_suf_i].unique().shape[0] == 1):
                    #print(x_suf, ' - very good suf')
                    x_to_lemms_suffs[x_suf] = list(df[df[x_suf_i] == x_suf][lemma_suf_i])[0]
                else:
                    if (i < end - 1):
                        bad_x_suf_set.add(x_suf)
                    x_to_lemms_suffs[x_suf] = get_most_frequent_lemma(df[df[x_suf_i] == x_suf][lemma_suf_i])
                        
    return x_to_lemms_suffs, bad_x_suf_set

# %%
# %time dict_N, _ = get_lemmarization_dict(train_N)
# Out:
# Wall time: 18 s

# %%
# %time dict_A, _ = get_lemmarization_dict(train_A)
# Out:
# Wall time: 21 s

# %%
# %time dict_V, _ = get_lemmarization_dict(train_V)
# Out:
# Wall time: 12min 27s

# %%
#keys = dt.keys()
def get_lemma(string, dt):
    for i in np.arange(9, 2, -1):
        if (string[-i:] in dt.keys()):
            return string[:-i] + dt[string[-i:]]

train_V['lemma_pred'] = train_V['X'].apply(lambda x: get_lemma(x, dict_V))
train_N['lemma_pred'] = train_N['X'].apply(lambda x: get_lemma(x, dict_N))
train_A['lemma_pred'] = train_A['X'].apply(lambda x: get_lemma(x, dict_A))

# %%
print(train_V[train_V['lemma_pred'] != train_V['lemmas']].shape[0] / float(train_V.shape[0]))
print(train_N[train_N['lemma_pred'] != train_N['lemmas']].shape[0] / float(train_N.shape[0]))
print(train_A[train_A['lemma_pred'] != train_A['lemmas']].shape[0] / float(train_A.shape[0]))
# Out:
# 0.009614887032839652
# 0.00361328125
# 0.011619566776646105

# %% [markdown]
# # final solution

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(min_df=5, max_df=.7,
                             max_features=None,
                             ngram_range=(3, 5),
                             lowercase=False,
                             analyzer='char_wb', 
                             binary=True)
vectorizer.fit(train['X'])
X = vectorizer.transform(train['X'])
X_test = vectorizer.transform(test['X'])
X.shape
# Out:
# (120803, 37412)

# %%
clf = LogisticRegression(multi_class='ovr', class_weight='balanced')
clf.fit(X, train['y'])
accuracy_score(train['y'], clf.predict(X))
# Out:
# 0.97552213107290386

# %%
test['y'] = clf.predict(X_test)

# %%
def get_lemma(string, dt):
    for i in np.arange(9, 2, -1):
        if (string[-i:] in dt.keys()):
            return string[:-i] + dt[string[-i:]]
    # so it is not in the recorded set (0.005 of all data)
    return string

def get_lemmatization(df, dt_V, dt_N, dt_A):
    if (str(df[2]) == 'V'):
        return get_lemma(df[1], dt_V)
    if (str(df[2]) == 'N'):
        return get_lemma(df[1], dt_N)
    if (str(df[2]) == 'A'):
        return get_lemma(df[1], dt_A)
    raise(BaseException('something went wrong' + str(df[2])))

# %%
# %time test['lemma'] = test[['Id', 'X', 'y']].apply(lambda x: get_lemmatization(x, dict_V, dict_N, dict_A), axis=1)
# Out:
# Wall time: 1.08 s

# %%
test[test['lemma'].isnull()].shape[0] / float(test.shape[0])
# Out:
# 0.0

# %%
test[test['lemma'].isnull()].shape[0] / float(test.shape[0])
# Out:
# 0.00509086005192003

# %%
test[test['lemma'].isnull()]
# Out:
#           Id            X  y lemma
# 90        91       viados  N  None
# 539      540           lp  N  None
# 1976    1977            è  N  None
# 2117    2118       reduce  A  None
# 2203    2204        cifri  N  None
# 2218    2219    apostrofo  V  None
# 2720    2721    frattempo  A  None
# 2740    2741    incongrue  A  None
# 3281    3282          alt  N  None
# 3423    3424        break  N  None
# 3604    3605        hotel  N  None
# 3695    3696      shockan  V  None
# 3712    3713        rosea  A  None
# 3922    3923         puoi  N  None
# 3982    3983    partecipe  V  None
# 4115    4116  redistribuo  V  None
# 4464    4465          blu  N  None
# 4531    4532    agrodolce  A  None
# 5016    5017         golf  N  None
# 5074    5075       timing  A  None
# 5350    5351         city  N  None
# 5425    5426         ciel  N  None
# 5480    5481    contemplo  V  None
# 5578    5579       scalfo  V  None
# 5819    5820          sax  N  None
# 6097    6098       ripulì  V  None
# 6351    6352        vertè  V  None
# 6443    6444          gap  N  None
# 6532    6533         guaì  N  None
# 6678    6679       pigmee  A  None
# ...      ...          ... ..   ...
# 25209  25210         tipa  N  None
# 25403  25404      western  V  None
# 25572  25573    décolleté  N  None
# 25584  25585        ficus  N  None
# 25834  25835    antitrust  A  None
# 25979  25980      bistrot  N  None
# 26265  26266           dj  N  None
# 26286  26287       riacue  V  None
# 26460  26461       grafic  A  None
# 26797  26798        alveò  V  None
# 26843  26844    individuò  V  None
# 27000  27001     polaroid  N  None
# 27039  27040          off  V  None
# 27372  27373       yogurt  N  None
# 27446  27447         turn  N  None
# 27591  27592    superfluo  N  None
# 27625  27626      scaturì  V  None
# 27807  27808   antiticket  A  None
# 28008  28009         afri  N  None
# 28430  28431       pampas  N  None
# 28514  28515        sceme  A  None
# 28560  28561         coté  N  None
# 28829  28830     coacervo  N  None
# 28861  28862    anti-expo  A  None
# 28862  28863      insinuò  V  None
# 29091  29092        kitch  N  None
# 29138  29139         kiwi  N  None
# 29200  29201  redistribua  V  None
# 29281  29282         baby  N  None
# 29310  29311           dì  N  None
#
# [151 rows x 4 columns]

# %%
answer = pd.read_csv('task2_lemmas_sample_submission')
answer['Category'] = test[['lemma', 'y']].apply(lambda x: '+'.join(x), axis=1)
answer.to_csv('task2_logregr_l2_balanced_ngram_3_5_lemma_suf_3_9', index=False)
answer.head()
# Out:
#    Id          Category
# 0   1       gettonare+V
# 1   2     incidentale+A
# 2   3       involtare+V
# 3   4           lievo+N
# 4   5  comunistizzare+V

# %%
test.head()
# Out:
#    Id                X  y           lemma
# 0   1         gettonan  V       gettonare
# 1   2      incidentali  A     incidentale
# 2   3        involtino  V       involtare
# 3   4            lievi  N           lievo
# 4   5  comunistizzasse  V  comunistizzare
